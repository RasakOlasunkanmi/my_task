# %%
# import neccesary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns", 1000)
pd.set_option("display.max_rows", 1000)
pd.set_option("display.width", 1000)

# %%
df = pd.read_csv("College Data.csv")
df
# Out:
#        College ID       Country  Total Students   Male  Female       CGPA  Annual Family Income                   Branch      Sports  Research Papers Published  Placement Rate  Faculty Count
# 0      College 52            UK           27002   2593   11644  10.000000               3574250                  Physics    Swimming                         39          100.00            655
# 1      College 93   Switzerland           11913   9392    2521   6.951278                762556     Chemical Engineering   Athletics                         31           68.84            256
# 2      College 15         Japan           15644   5475    4388   9.327922               1795845  Business Administration  Volleyball                         37           91.99            555
# 3      College 72     Singapore           13239   7363    5876   8.681112               1222223                  Physics      Tennis                         48           97.98            455
# ...

# %%
df.columns
# Out:
# Index(['College ID', 'Country', 'Total Students', 'Male', 'Female', 'CGPA', 'Annual Family Income', 'Branch', 'Sports', 'Research Papers Published', 'Placement Rate', 'Faculty Count'], dtype='object')

# %%
df.columns = ['college_id', 'country', 'total_students', 'male', 'female', 'cgpa', 'annual_family_income', 'branch', 'sports', 'research_papers_published', 'placement_rate', 'faculty_count']

# %%
df.columns
# Out:
# Index(['college_id', 'country', 'total_students', 'male', 'female', 'cgpa', 'annual_family_income', 'branch', 'sports', 'research_papers_published', 'placement_rate', 'faculty_count'], dtype='object')

# %%
df.head(10)
# Out:
#    college_id      country  total_students   male  female       cgpa  annual_family_income                   branch      sports  research_papers_published  placement_rate  faculty_count
# 0  College 52           UK           27002   2593   11644  10.000000               3574250                  Physics    Swimming                         39          100.00            655
# 1  College 93  Switzerland           11913   9392    2521   6.951278                762556     Chemical Engineering   Athletics                         31           68.84            256
# 2  College 15        Japan           15644   5475    4388   9.327922               1795845  Business Administration  Volleyball                         37           91.99            555
# 3  College 72    Singapore           13239   7363    5876   8.681112               1222223                  Physics      Tennis                         48           97.98            455
# ...

# %%
df.dtypes
# Out:
# college_id                    object
# country                       object
# total_students                 int64
# male                           int64
# female                         int64
# cgpa                         float64
# annual_family_income           int64
# branch                        object
# sports                        object
# research_papers_published      int64
# placement_rate               float64
# faculty_count                  int64
# dtype: object

# %%
df.describe()
# Out:
#        total_students          male        female          cgpa  annual_family_income  research_papers_published  placement_rate  faculty_count
# count    50000.000000  50000.000000  50000.000000  50000.000000          5.000000e+04               50000.000000    50000.000000   50000.000000
# mean     15522.357440   7747.061900   3555.550780      8.705289          2.611606e+06                  24.472300       82.335352     428.919520
# std       8366.792001   4188.406336   5892.297104      1.053363          1.387889e+06                  14.458858       11.475691     154.733223
# min       1001.000000    500.000000 -13917.000000      4.001559          2.000040e+05                   0.000000       60.000000      62.000000
# 25%       8272.750000   4111.000000    527.000000      7.980137          1.408786e+06                  12.000000       72.450000     315.000000
# ...

# %%
df.shape
# Out:
# (50000, 12)

# %%
df.isna().sum()
# Out:
# college_id                   0
# country                      0
# total_students               0
# male                         0
# female                       0
# cgpa                         0
# annual_family_income         0
# branch                       0
# sports                       0
# research_papers_published    0
# placement_rate               0
# faculty_count                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Replacing the negative values in the 'female' column
df['female'] = df['female'].clip(lower=0)
df.head(10)
# Out:
#    college_id      country  total_students   male  female       cgpa  annual_family_income                   branch      sports  research_papers_published  placement_rate  faculty_count
# 0  College 52           UK           27002   2593   11644  10.000000               3574250                  Physics    Swimming                         39          100.00            655
# 1  College 93  Switzerland           11913   9392    2521   6.951278                762556     Chemical Engineering   Athletics                         31           68.84            256
# 2  College 15        Japan           15644   5475    4388   9.327922               1795845  Business Administration  Volleyball                         37           91.99            555
# 3  College 72    Singapore           13239   7363    5876   8.681112               1222223                  Physics      Tennis                         48           97.98            455
# ...

# %%
# Rounding column 'cgpa' and 'placement_rate' to 2 decimal places
df[['cgpa', 'placement_rate']] = round(df[['cgpa', 'placement_rate']], 2)

# %%
df.head(10)
# Out:
#    college_id      country  total_students   male  female   cgpa  annual_family_income                   branch      sports  research_papers_published  placement_rate  faculty_count
# 0  College 52           UK           27002   2593   11644  10.00               3574250                  Physics    Swimming                         39          100.00            655
# 1  College 93  Switzerland           11913   9392    2521   6.95                762556     Chemical Engineering   Athletics                         31           68.84            256
# 2  College 15        Japan           15644   5475    4388   9.33               1795845  Business Administration  Volleyball                         37           91.99            555
# 3  College 72    Singapore           13239   7363    5876   8.68               1222223                  Physics      Tennis                         48           97.98            455
# ...

# %%
df['country'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995     True
# 49996     True
# 49997     True
# 49998     True
# 49999     True
# Name: country, Length: 50000, dtype: bool

# %% [markdown]
# 1) total no of students overall
# 2) college with the highest no of student
# 3) country with highest no of college
# 4) college with the student that has the highest cgpa
# 5) college & country with the highest annual family income.
#
# KPI
# 1) After checking unique index - do Total annual family income for each of the idexed country.
# 2) Total faculty for the unique indexed country
# 3) Total no of branch & sport in each college
# 4) No of college owned by each country
# 5) Total number of research_papers_published

# %%
#1. Total number of students

Total_of_students = df["total_students"].sum()
Total_of_students
# Out:
# 776117872

# %%
#2. Total annual family income

Total_annual_family_income = df["annual_family_income"].sum()
Total_annual_family_income
# Out:
# 130580278273

# %%
#3. Total colleges

Total_colleges = df["college_id"].count()
Total_colleges
# Out:
# 50000

# %%
#4. Average CGPA

Average_cgpa = round(df["cgpa"].mean(), 2)
Average_cgpa
# Out:
# 8.71

# %%
#5. Total Placement Rate

Total_placement_rate = df["placement_rate"].sum()
Total_placement_rate
# Out:
# 4116767.5900000003

# %%
df['placement_rate_percentage'] = (df['placement_rate'] / Total_placement_rate) * 100

# %%
df
# Out:
#        college_id       country  total_students   male  female   cgpa  annual_family_income                   branch      sports  research_papers_published  placement_rate  faculty_count  placement_rate_percentage
# 0      College 52            UK           27002   2593   11644  10.00               3574250                  Physics    Swimming                         39          100.00            655                   0.002429
# 1      College 93   Switzerland           11913   9392    2521   6.95                762556     Chemical Engineering   Athletics                         31           68.84            256                   0.001672
# 2      College 15         Japan           15644   5475    4388   9.33               1795845  Business Administration  Volleyball                         37           91.99            555                   0.002235
# ...

# %%
# Average placement rate
Average_placement_rate_percentage = df["placement_rate_percentage"].mean()
Average_placement_rate_percentage
# Out:
# 0.0019999999999999996

# %%
# Average annual family income
Average_annual_family_income = df["annual_family_income"].mean()
Average_annual_family_income
# Out:
# 2611605.56546

# %%
# Total faculty count
Total_faculty_count = df["faculty_count"].sum()
Total_faculty_count
# Out:
# 21445976

# %%
#6. Average faculty count per college
Average_faculty_count_per_college = round(Total_faculty_count / Total_colleges, 2)
Average_faculty_count_per_college
# Out:
# 428.92

# %%
#7. Total research papers published

Total_research_papers_published = df["research_papers_published"].sum()
Total_research_papers_published
# Out:
# 1223615

# %%
df.set_index("country", inplace=True)

# %%
df.head(10)
# Out:
#              college_id  total_students   male  female   cgpa  annual_family_income                   branch      sports  research_papers_published  placement_rate  faculty_count  placement_rate_percentage
# country
# UK           College 52           27002   2593   11644  10.00               3574250                  Physics    Swimming                         39          100.00            655                   0.002429
# Switzerland  College 93           11913   9392    2521   6.95                762556     Chemical Engineering   Athletics                         31           68.84            256                   0.001672
# Japan        College 15           15644   5475    4388   9.33               1795845  Business Administration  Volleyball                         37           91.99            555                   0.002235
# ...

# %%
df.index
# Out:
# Index(['UK', 'Switzerland', 'Japan', 'Singapore', 'Canada', 'USA', 'UK', 'China', 'Singapore', 'China',
#        ...
#        'Switzerland', 'Australia', 'Australia', 'Switzerland', 'Japan', 'India', 'Japan', 'South Africa', 'USA', 'China'], dtype='object', name='country', length=50000)

# %%
# list of all the locations or countries where all the customers purchase from
unique_index = df.index.unique().sort_values()
unique_index
# Out:
# Index(['Australia', 'Canada', 'China', 'India', 'Japan', 'Singapore', 'South Africa', 'Switzerland', 'UK', 'USA'], dtype='object', name='country')

# %%
len(unique_index)
# Out:
# 10

# %%
df.index.value_counts().head(10)
# Out:
# country
# China           5052
# South Africa    5052
# Switzerland     5025
# Australia       5018
# Singapore       5013
# Japan           4991
# USA             4985
# Canada          4974
# UK              4945
# India           4945
# Name: count, dtype: int64

# %%
df.loc['China', 'annual_family_income'].sum()
# Out:
# 13349884361

# %%
df.loc['China', 'faculty_count'].sum()
# Out:
# 2174053
