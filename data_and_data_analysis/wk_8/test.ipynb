# %% [markdown]
# # Injesting Dta From External Source

# %% [markdown]
# ## From Github

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Divine123-glitch/Data/refs/heads/main/College%20Data.csv'
data = pd.read_csv(url, sep=',')
data.head()
# Out:
#    College ID      Country  Total Students   Male  Female       CGPA  \
# 0  College 52           UK           27002   2593   11644  10.000000
# 1  College 93  Switzerland           11913   9392    2521   6.951278
# 2  College 15        Japan           15644   5475    4388   9.327922
# 3  College 72    Singapore           13239   7363    5876   8.681112
# 4  College 61       Canada           10236  13339   -3103   8.560567
#
#    Annual Family Income                   Branch      Sports  \
# 0               3574250                  Physics    Swimming
# 1                762556     Chemical Engineering   Athletics
# 2               1795845  Business Administration  Volleyball
# 3               1222223                  Physics      Tennis
# 4               1921133            Biotechnology   Athletics
#
#    Research Papers Published  Placement Rate  Faculty Count
# 0                         39          100.00            655
# 1                         31           68.84            256
# ...

# %% [markdown]
# ## From Google Drive
#
# **% for ipynb sharing**
#
# **! for collab sharing**

# %%
import gdown as gd
raw_url = 'https://drive.google.com/file/d/13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb/view?usp=drive_link'
id = '13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb'

gd.download(id = id, output = 'Accident.csv', quiet=False)

df = pd.read_csv('Accident.csv', sep=',')
df.head()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb
# To: c:\Users\olasunkanmi\Desktop\my_task\data_and_data_analysis\wk_8\Accident.csv
# 100%|██████████| 72.3M/72.3M [02:08<00:00, 564kB/s]
#   Accident_Index  Number_of_Vehicles  Number_of_Casualties        Date   Time  \
# 0  197901A1SEE71                   2                     1  1979-01-01  18:20
# 1  197901A2JDW40                   1                     1  1979-02-01  09:15
# 2  197901A4IJV90                   2                     1  1979-04-01  08:45
# 3  197901A4NIE33                   2                     1  1979-04-01  13:40
# 4  197901A4SKO47                   2                     1  1979-04-01  18:50
#
#    Speed_limit Road_conditions Weather_conditions       Day         Road_type  \
# 0         50.0            Snow            Unknown    Monday  Dual carriageway
# 1         30.0            Snow            Unknown   Tuesday           Unknown
# ...

# %%
raw_link = 'https://drive.google.com/file/d/1I-VAgb1OH0OYRJh3P6yOaMVjZjYxhAki/view?usp=drive_link'
id = '1I-VAgb1OH0OYRJh3P6yOaMVjZjYxhAki'

gd.download(f"https://drive.google.com/uc?id={id}", quiet=False)     # gd.download(id = id, output = 'car45_data.csv', quiet=False)

df1 = pd.read_csv('car45_data.csv', sep=',')
df1.head()
df2 = df1.copy()
df2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1I-VAgb1OH0OYRJh3P6yOaMVjZjYxhAki
# To: c:\Users\olasunkanmi\Desktop\my_task\data_and_data_analysis\wk_8\car45_data.csv
# 100%|██████████| 554k/554k [00:02<00:00, 197kB/s]
#       Unnamed: 0                    car_id  \
# 0              0  5IQTDBTYmvK1tJwhdvGJfESJ
# 1              1  zpZUGomoVXuKk9UFa8j8moC9
# 2              2  a6ShZXOX4KtY6IBGJIcF3Cxk
# 3              3  CciPNDN6vhhQQI1FTQHAbfxi
# 4              4  bvwd5LDMx6mIYpVa6Uhi2jqJ
# ...          ...                       ...
# 2889        4348  sHnZZvambm9Prcwq4IwKPmGi
# 2890        4349  fsa5b9HiCDnZt2P0Sf9qKLJN
# 2891        4350  uE5eXlbAEMfHSMZ0SYahHP8x
# 2892        4351  CzI81oX5BIFITuoFozBtnQLS
# 2893        4352  41KZsjPRmovhziJJQ3gkw37Q
#
#                                   description    amount  \
# 0                   Lexus ES 350 FWD 2013 Red  12937500
# 1           Land Rover Range Rover 2012 White   6750000
# ...

# %% [markdown]
# ## From Wikipedia

# %%
import requests

url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
headers = {'User-Agent': 'Chrome/140'}
response = requests.get(url, headers = headers)
un = pd.read_html(response.text)
country = un[2]
country.head()
# Out:
# C:\Users\user49\AppData\Local\Temp\ipykernel_4164\1453477866.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   un = pd.read_html(response.text)
#   Country/Territory IMF (2025)[1][6] World Bank (2022–24)[7]  \
# 0             World        113795678               111326370
# 1     United States         30507217                29184890
# 2        China[n 1]         19231705                18743803
# 3           Germany          4744804                 4659929
# 4             India          4187017                 3912686
#
#   United Nations (2023)[8]
# 0                100834796
# 1                 27720700
# 2                 17794782
# 3                  4525704
# 4                  3575778
