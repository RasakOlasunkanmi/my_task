# %%
# Verifying GPU Access:
import tensorflow as tf
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# **Working with Files**
#
# - Handling text files is crucial when working with large datasets or preparing prompts stored in external files.
#
# **Reading and Writing Text Files:**

# %%
# Reading files:
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-175753269.py in <cell line: 0>()
#       1 # Reading files:
# ----> 2 with open("example.txt", "r") as file:
#       3     content = file.read()
#       4     print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
# Assuming this path is verified in your File Explorer as correct:
file_path = r"C:\Users\olasunkanmi\Downloads\example.txt" 

try:
    with open(file_path, 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
    print("Please check the path and filename for typos.")
# Out:
# Error: The file was not found at C:\Users\olasunkanmi\Downloads\example.txt
# Please check the path and filename for typos.
